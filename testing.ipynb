# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("Test_data.csv")

# %%
data.tail()
# Out:
#       Entry     Exit  Quantity  Entry_date Entry_time   Exit_date Exit_time  \
# 44  1004.90  1003.75      14.0  2025-07-28   13:00:00  2025-07-28  14:00:00
# 45  1003.85  1005.30      14.0  2025-07-28   15:00:00  2025-07-29  09:45:00
# 46   950.65   960.40      15.0  2025-09-03   14:30:00  2025-09-04  09:15:00
# 47  1002.90  1003.25      14.0  2025-10-27   14:30:00  2025-10-28  09:15:00
# 48  1005.10  1008.45      14.0  2025-10-29   11:00:00  2025-10-29  12:00:00
#
#       PnL  Capital
# 44  -18.2  14636.0
# 45   16.8  14652.8
# 46  162.0  14814.8
# 47   60.9  14875.7
# 48   48.3  14924.0

# %%
plt.plot(data["Capital"])
